# %%
import cx_Oracle
import pandas as pd
import datetime
import os

def getData(user, password, database, targetTable, commandText):
    connection = cx_Oracle.connect(user, password, database)
    cursor = connection.cursor()
    cursor.execute(commandText.format(targetTable))
    x = cursor.description
    columns = [y[0] for y in x]
    cursor01 = cursor.fetchall()
    cursor.close()
    data = pd.DataFrame(cursor01, columns=columns)
    return data

# %%
user = 'dd_data'
password = 'xdf123'
database = 'LBORA170'
targetTable = 'soure_01'
commandText = '''select t.STD_MODEL_INFO,t.GGID,t.CHINESE_CS from CS_JY_2 t'''
commandText1 = '''select t.STD_MODEL_INFO,t.GGID,t.MODEL_CATE_NAME from  A_MODEL_20190617 t'''

train_data = getData(user, password, database, targetTable, commandText)
train_data1 = getData(user, password, database, targetTable, commandText1)

# %%
train_data.head()
# Out:
#                                       STD_MODEL_INFO        GGID CHINESE_CS
# 0  轿车,手动档 进取型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06         精灵
# 1  轿车,手动档 舒适型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06         精灵
# 2     轿车,手动档 豪华型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200802.0  CC7130MM02         精灵
# 3     轿车,手动档 进取型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200906.0  CC7130MM02         精灵
# 4  轿车,手动档 尊贵型 GLX i 比亚迪QCJ7160A1轿车 比亚迪 国产 比亚迪F3 2...   QCJ7160A1      比亚迪f3

# %%
train_data1.head()
# Out:
#                                       STD_MODEL_INFO        GGID  \
# 0            扬天CXQ9391CXY仓栅式半挂车  扬天  安徽江淮扬天汽车股份有限公司   CXQ9391CXY
# 1                 徐州XCG240LC-8挖掘机  徐州  徐州徐挖机械制造有限公司   XCG240LC-8
# 2                 义德NLYW-9.0A挖掘机  义德  河北省故城县义德农用机械厂         None
# 3                    愚公WYL75轮式挖掘机  愚公  山东愚公工程机械有限公司         None
# 4  海粤HY5045XYYA押运车  海粤  中山市海粤汽车工业有限公司 发动机型号:庆铃4JB...  HY5045XYYA
#
#   MODEL_CATE_NAME
# 0              扬天
# 1              徐州
# 2              义德
# 3              愚公
# 4              海粤

# %%
train_data['MODEL_CATE_NAME']=train_data['CHINESE_CS']
train_data.drop('CHINESE_CS',axis=1,inplace=True)
train_data.head()
# Out:
#                                       STD_MODEL_INFO        GGID  \
# 0  轿车,手动档 进取型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06
# 1  轿车,手动档 舒适型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06
# 2     轿车,手动档 豪华型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200802.0  CC7130MM02
# 3     轿车,手动档 进取型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200906.0  CC7130MM02
# 4  轿车,手动档 尊贵型 GLX i 比亚迪QCJ7160A1轿车 比亚迪 国产 比亚迪F3 2...   QCJ7160A1
#
#   MODEL_CATE_NAME
# 0              精灵
# 1              精灵
# 2              精灵
# 3              精灵
# 4           比亚迪f3

# %%
train_data_all=pd.concat([train_data,train_data1],axis=0)
train_data_all.head()
# Out:
#                                       STD_MODEL_INFO        GGID  \
# 0  轿车,手动档 进取型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06
# 1  轿车,手动档 舒适型 国ⅢOBD 长城CC7130MM06轿车 长城 国产 精灵 200906.0  CC7130MM06
# 2     轿车,手动档 豪华型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200802.0  CC7130MM02
# 3     轿车,手动档 进取型 国Ⅳ 长城CC7130MM02轿车 长城 国产 精灵 200906.0  CC7130MM02
# 4  轿车,手动档 尊贵型 GLX i 比亚迪QCJ7160A1轿车 比亚迪 国产 比亚迪F3 2...   QCJ7160A1
#
#   MODEL_CATE_NAME
# 0              精灵
# 1              精灵
# 2              精灵
# 3              精灵
# 4           比亚迪f3

# %%
train_data_all.to_csv('data/standard.txt', index=None, header=None,encoding='utf-8',sep='#')
